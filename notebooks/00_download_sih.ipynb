# %%
import os
import glob
import boto3
from pysus import SIH

# %%
ANO = 2025
vUF = "SP"
bucket = "datalake"
bronze_prefix = f"bronze/sih_sus/{ANO}/"
base_path = "/home/jovyan/pysus"

# %%
def conectar_minio():
    return boto3.client(
        "s3",
        endpoint_url=os.getenv("MINIO_ENDPOINT"),
        aws_access_key_id=os.getenv("MINIO_ROOT_USER"),
        aws_secret_access_key=os.getenv("MINIO_ROOT_PASSWORD")
    )

# %%
def baixar_sih():
    print("Baixando dados SIH...")
    sih = SIH().load() 
    files = sih.get_files("RD", uf=vUF, year=ANO)
    sih.download(files)     
    print("Download concluído.")

# %%
arquivos = glob.glob(f"{base_path}/**/*.parquet",recursive=True)
print(f"{len(arquivos)} arquivos encontrados.")

for arquivo in arquivos:
    if os.path.isfile(arquivo):
        caminho_relativo = os.path.relpath(arquivo, base_path)
        destino = bronze_prefix + caminho_relativo.replace("\\", "/")

        s3.upload_file(arquivo, bucket, destino)
        print(f"✔ Enviado: {caminho_relativo}")
# Out:
# 116 arquivos encontrados.
# ✔ Enviado: RDSP2501.parquet/bc2333fed9564c13b60746a88defc20e-0.parquet
# ✔ Enviado: RDSP2501.parquet/d8c7a2f83f33483b88a5dff88aaefe08-0.parquet
# ✔ Enviado: RDSP2501.parquet/653a1a620b264d3db117dcb83e57c5eb-0.parquet
# ✔ Enviado: RDSP2501.parquet/922525d50e354c2c8bdc7e31ba688611-0.parquet
# ✔ Enviado: RDSP2501.parquet/7d14917183b3465f8af57ea9f35fd2b6-0.parquet
# ✔ Enviado: RDSP2501.parquet/7e06c60151cc4390a81adfca054b63dd-0.parquet
# ✔ Enviado: RDSP2501.parquet/58a8414abeb94ed8b96bb4016f05532c-0.parquet
# ✔ Enviado: RDSP2501.parquet/16059854c10d41689813b9c41769cb96-0.parquet
# ✔ Enviado: RDSP2507.parquet/b68f0fcfe6544458ba36ccd18a4f97bc-0.parquet
# ✔ Enviado: RDSP2507.parquet/1d7967ff7b304b1fa7bf6acfdd55f3ce-0.parquet
# ✔ Enviado: RDSP2507.parquet/2302e74ccf044d4bb5056e5033f7a168-0.parquet
# ✔ Enviado: RDSP2507.parquet/c214e4ca16e74107a0f355caccc24630-0.parquet
# ✔ Enviado: RDSP2507.parquet/5cc681d499b541b2adedaf489d525d6a-0.parquet
# ✔ Enviado: RDSP2507.parquet/03bbe163c1e64deea64eee1e15968d08-0.parquet
# ✔ Enviado: RDSP2507.parquet/e8334e1ca98948db9051de1005f056e0-0.parquet
# ✔ Enviado: RDSP2507.parquet/54d62262fd02464a92a2952e4053e353-0.parquet
# ✔ Enviado: RDSP2507.parquet/512f4042c93a45d68f305a76c3d4e57f-0.parquet
# ✔ Enviado: RDSP2505.parquet/060a1e5adc1c41b79293d770988e5d51-0.parquet
